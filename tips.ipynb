# %% [markdown]
# ## スライド

# %% [markdown]
# 英語で書かれた論文はローマ字

# %% [markdown]
# 相手にとって必要な情報は何

# %% [markdown]
# グラフの軸は大きく

# %% [markdown]
# パラメータの説明必須（相手にとって必要かどうか）

# %% [markdown]
# 目次を入れて、かつ、内容の変わるときは切り替えのときにもう一回目次を入れて、強調

# %% [markdown]
# 1.(半角)

# %% [markdown]
# 背景と自分の研究の割合

# %% [markdown]
# URLで引用
