# %%
alpha = ["0.55","0.60",'0.65',"0.70","0.75","0.80","0.85","0.90","0.95","1.0"]

# %%
for a in alpha:
    with open("/home/kakeya/Desktop/tanimoto/data/slice/hist_" + a,  "/path/case_00" + sx + ".txt") as f1:
        with open("/home/kakeya/Desktop/tanimoto/data/slice/hist_" + a,  "/path/case_00" + sx + ".txt") as f2:
            with open("/home/kakeya/Desktop/tanimoto/data/slice/hist_" + a,  "/path/case_00" + sx + ".txt") as f3:
